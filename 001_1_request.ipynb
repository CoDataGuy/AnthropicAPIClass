# %% [markdown]
# Multi Turn Conversation Lesson
# Claude does not remember previous conversations

# %%
# Load Env Variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# verify key loaded
from dotenv import load_dotenv
import os

# Get the directory where your notebook is located
notebook_dir = os.path.dirname(os.path.abspath("__file__"))
env_path = os.path.join(notebook_dir, '.env')


# Check what directory Jupyter is using
print(f"Current working directory: {os.getcwd()}")
print(f"Files in directory: {os.listdir('.')}")

# Verify the key loaded
api_key = os.environ.get("ANTHROPIC_API_KEY")
print(f"API Key loaded: {api_key[:20]}..." if api_key else "API Key NOT found")
# Out:
# Current working directory: c:\Users\shann\Documents\AnthropicAPI
# Files in directory: ['.env', '001_request.ipynb']
# API Key loaded: sk-ant-api03-HfRsIGt...

# %%
# Create API Client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
#helper functions lecture multi turn capture chat history

def add_user_message (messages, text):
    user_message = {"role": "user", "content" : text}
    messages.append(user_message)

def add_assistant_message (messages, text):
    assistant_message = {"role": "assistant", "content" : text}
    messages.append(assistant_message)



def chat(messages): 
    message = client.messages.create (
     model=model,
        max_tokens = 1000,
        messages= messages,

    )
    return message.content[0].text

# %%
# Make a starting list of messages
messages = []

# Call the function (note the parentheses)
add_user_message(messages, "Define quantum computing in one sentence")

messages

# Pass the list of messages into 'chat' to get an an answer
answer = chat(messages)

answer

# Take the answer and add it as an assistant message into our list
add_assistant_message(messages, answer)

# add in the user's follow up question
add_user_message(messages, "Write another sentence")
# Call the chat agent again with the list of messaes to get a final answer
answer = chat(messages)
answer
# Out:
# 'Quantum computers have the potential to revolutionize fields such as cryptography, drug discovery, and artificial intelligence by solving complex problems that are currently intractable for even the most powerful classical supercomputers.'
